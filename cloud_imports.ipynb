# %%
# !conda install matplotlib gymnasium numpy -y
# !pip install pygame
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gymnasium
#     - matplotlib
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.13            |       hb9d3cd8_0         547 KB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     cairo-1.18.2               |       h3394656_1         956 KB  conda-forge
# ...

# %%
import torch

# %%
test = torch.randn(3, 2, 2, 2)
len(test.shape)
# Out:
# 4
